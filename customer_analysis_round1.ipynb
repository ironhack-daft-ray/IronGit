# %%
import numpy as np

# %%
import pandas as pd

# %%
file1 = pd.read_csv('/Users/rayanhawili/Desktop/IR_DAFT/Course/Unit_2/lab-customer-analysis-round-1-master/files_for_lab/csv_files/file1.csv')

# %%
file1.columns = file1.columns.str.lower()

# %%
file1.rename(columns={'st':'state'}, inplace=True)

# %%
file1.head()
# Out:
#   customer       state gender             education customer lifetime value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     income  monthly premium auto number of open complaints     policy type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    vehicle class  total claim amount
# ...

# %%
file1.shape
# Out:
# (4008, 11)

# %%
file2 = pd.read_csv('/Users/rayanhawili/Desktop/IR_DAFT/Course/Unit_2/lab-customer-analysis-round-1-master/files_for_lab/csv_files/file2.csv')

# %%
file2.columns = file2.columns.str.lower()

# %%
file2.rename(columns={'st':'state'}, inplace=True)

# %%
file2=file2[['customer', 'state', 'gender', 'education', 'customer lifetime value',
       'income', 'monthly premium auto', 'number of open complaints',
       'policy type', 'vehicle class', 'total claim amount']]

# %%
file2.head()
# Out:
#   customer       state gender education customer lifetime value  income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
# 2  MY31220  California      F   College              899704.02%   54230
# 3  UH35128      Oregon      F   College             2580706.30%   71210
# 4  WH52799     Arizona      F   College              380812.21%   94903
#
#    monthly premium auto number of open complaints     policy type  \
# 0                    88                    1/0/00   Personal Auto
# 1                   114                    1/0/00    Special Auto
# 2                   112                    1/0/00   Personal Auto
# 3                   214                    1/1/00   Personal Auto
# 4                    94                    1/0/00  Corporate Auto
#
#    vehicle class  total claim amount
# 0  Four-Door Car               633.6
# 1            SUV               547.2
# ...

# %%
file2.shape
# Out:
# (996, 11)

# %%
file3 = pd.read_csv('/Users/rayanhawili/Desktop/IR_DAFT/Course/Unit_2/lab-customer-analysis-round-1-master/files_for_lab/csv_files/file3.csv')

# %%
file3.columns = file3.columns.str.lower()

# %%
file3=file3[['customer', 'state', 'gender', 'education', 'customer lifetime value',
       'income', 'monthly premium auto', 'number of open complaints',
       'policy type', 'vehicle class', 'total claim amount']]

# %%
file3.head()
# Out:
#   customer       state gender             education  customer lifetime value  \
# 0  SA25987  Washington      M  High School or Below              3479.137523
# 1  TB86706     Arizona      M                Master              2502.637401
# 2  ZL73902      Nevada      F              Bachelor              3265.156348
# 3  KX23516  California      F  High School or Below              4455.843406
# 4  FN77294  California      M  High School or Below              7704.958480
#
#    income  monthly premium auto  number of open complaints    policy type  \
# 0       0                   104                          0  Personal Auto
# 1       0                    66                          0  Personal Auto
# 2   25820                    82                          0  Personal Auto
# 3       0                   121                          0  Personal Auto
# 4   30366                   101                          2  Personal Auto
#
#    vehicle class  total claim amount
# ...

# %%
file3.shape
# Out:
# (7070, 11)

# %%
column_names = file1.columns

# %%
data = pd.DataFrame(columns=column_names)

# %%
data.head()
# Out:
# Empty DataFrame
# Columns: [customer, state, gender, education, customer lifetime value, income, monthly premium auto, number of open complaints, policy type, vehicle class, total claim amount]
# Index: []

# %%
data.columns
# Out:
# Index(['customer', 'state', 'gender', 'education', 'customer lifetime value',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'policy type', 'vehicle class', 'total claim amount'],
#       dtype='object')

# %%
data.shape
# Out:
# (0, 11)

# %%
data=pd.concat([data,file1],axis=0)

# %%
data=pd.concat([data,file2],axis=0)

# %%
data=pd.concat([data,file3],axis=0)

# %%
data.shape
# Out:
# (12074, 11)

# %%
data=data.drop(['education'],axis=1)

# %%
data=data.drop(['number of open complaints'],axis=1)

# %%
data.columns
# Out:
# Index(['customer', 'state', 'gender', 'customer lifetime value', 'income',
#        'monthly premium auto', 'policy type', 'vehicle class',
#        'total claim amount'],
#       dtype='object')

# %%
data.head()
# Out:
#   customer       state gender customer lifetime value   income  \
# 0  RB50392  Washington    NaN                     NaN      0.0
# 1  QZ44356     Arizona      F              697953.59%      0.0
# 2  AI49188      Nevada      F             1288743.17%  48767.0
# 3  WW63253  California      M              764586.18%      0.0
# 4  GA49547  Washington      M              536307.65%  36357.0
#
#    monthly premium auto     policy type  vehicle class  total claim amount
# 0                1000.0   Personal Auto  Four-Door Car            2.704934
# 1                  94.0   Personal Auto  Four-Door Car         1131.464935
# 2                 108.0   Personal Auto   Two-Door Car          566.472247
# 3                 106.0  Corporate Auto            SUV          529.881344
# 4                  68.0   Personal Auto  Four-Door Car           17.269323

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12074 entries, 0 to 7069
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   customer                 9137 non-null   object
#  1   state                    9137 non-null   object
#  2   gender                   9015 non-null   object
#  3   customer lifetime value  9130 non-null   object
#  4   income                   9137 non-null   float64
#  5   monthly premium auto     9137 non-null   float64
#  6   policy type              9137 non-null   object
#  7   vehicle class            9137 non-null   object
#  8   total claim amount       9137 non-null   float64
# dtypes: float64(3), object(6)
# memory usage: 943.3+ KB

# %%
#create a temp data set copy
tempdata=data.copy()

# %%
# find data type
tempdata.dtypes
# Out:
# customer                    object
# state                       object
# gender                      object
# customer lifetime value     object
# income                     float64
# monthly premium auto       float64
# policy type                 object
# vehicle class               object
# total claim amount         float64
# dtype: object

# %%
# changing data types
tempdata["customer lifetime value"] = pd.to_numeric(tempdata["customer lifetime value"],errors='coerce')

# %%
# find data type
tempdata.dtypes
# Out:
# customer                    object
# state                       object
# gender                      object
# customer lifetime value    float64
# income                     float64
# monthly premium auto       float64
# policy type                 object
# vehicle class               object
# total claim amount         float64
# dtype: object

# %%
# Correct the values in the column customer lifetime value.
# They are given as a percent, so multiply them by 100
tempdata['customer lifetime value'] = tempdata['customer lifetime value']*100

# %%
# Check for duplicate rows in the data and remove if any.
# DataFrame.duplicated(subset=None, keep='first') #check if this would work to keep the first duplicate value
tempdata = tempdata.drop_duplicates()

# %%
# Filter out the data for customers who have an income of 0 or less.
# data[(data["gender"]=="M") & (data["state"]=="FL")]
# THIS IS NOT WORKING ALL TIMES data.query('gender=="M" & state=="FL" ')

# %%
# in case we want to reset the index
#data = data.reset_index(drop=True)
# Out:
#      customer       state gender customer lifetime value   income  \
# 0     RB50392  Washington    NaN                     NaN      0.0
# 1     QZ44356     Arizona      F              697953.59%      0.0
# 2     AI49188      Nevada      F             1288743.17%  48767.0
# 3     WW63253  California      M              764586.18%      0.0
# 4     GA49547  Washington      M              536307.65%  36357.0
# ...       ...         ...    ...                     ...      ...
# 7065  LA72316  California      M                   23406  71941.0
# 7066  PK87824  California      F                 3096.51  21604.0
# 7067  TD14365  California      M                 8163.89      0.0
# 7068  UP19263  California      M                 7524.44  21941.0
# 7069  Y167826  California      M                 2611.84      0.0
#
#       monthly premium auto     policy type  vehicle class  total claim amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
datafiltered = data[(data['gender']== 'M')]

# %%
datafiltered
# Out:
#      customer       state gender customer lifetime value   income  \
# 3     WW63253  California      M              764586.18%      0.0
# 4     GA49547  Washington      M              536307.65%  36357.0
# 7     CF85061     Arizona      M              721610.03%      0.0
# 8     DY87989      Oregon      M             2412750.40%  14072.0
# 10    SX51350  California      M              473899.20%      0.0
# ...       ...         ...    ...                     ...      ...
# 7063  TF56202  California      M                 5032.17  66367.0
# 7065  LA72316  California      M                   23406  71941.0
# 7067  TD14365  California      M                 8163.89      0.0
# 7068  UP19263  California      M                 7524.44  21941.0
# 7069  Y167826  California      M                 2611.84      0.0
#
#       monthly premium auto     policy type  vehicle class  total claim amount
# 3                    106.0  Corporate Auto            SUV          529.881344
# ...

# %%
datafiltered=datafiltered.reset_index(drop=True)

# %%
datafiltered
# Out:
#      customer       state gender customer lifetime value   income  \
# 0     WW63253  California      M              764586.18%      0.0
# 1     GA49547  Washington      M              536307.65%  36357.0
# 2     CF85061     Arizona      M              721610.03%      0.0
# 3     DY87989      Oregon      M             2412750.40%  14072.0
# 4     SX51350  California      M              473899.20%      0.0
# ...       ...         ...    ...                     ...      ...
# 4363  TF56202  California      M                 5032.17  66367.0
# 4364  LA72316  California      M                   23406  71941.0
# 4365  TD14365  California      M                 8163.89      0.0
# 4366  UP19263  California      M                 7524.44  21941.0
# 4367  Y167826  California      M                 2611.84      0.0
#
#       monthly premium auto     policy type  vehicle class  total claim amount
# 0                    106.0  Corporate Auto            SUV          529.881344
# ...

# %%
# show specific rows
datafiltered[1:15]
# Out:
#    customer       state gender customer lifetime value   income  \
# 1   GA49547  Washington      M              536307.65%  36357.0
# 2   CF85061     Arizona      M              721610.03%      0.0
# 3   DY87989      Oregon      M             2412750.40%  14072.0
# 4   SX51350  California      M              473899.20%      0.0
# 5   QK46697  Washington      M              617710.93%  61040.0
# 6   HS14476  Washington      M              916206.32%  29723.0
# 7   YD87931  Washington      M              495165.61%  46896.0
# 8   GP39118  Washington      M              499655.27%  71600.0
# 9   DS81757      Oregon      M              247012.12%      0.0
# 10  OJ94107          AZ      M              561906.85%  50335.0
# 11  ZU18643      Nevada      M              366077.03%  64495.0
# 12  EK59571      Oregon      M              388545.64%      0.0
# 13  RO18530  Washington      M              254068.98%  42557.0
# 14  PD27940     Arizona      M              488516.25%  26372.0
#
# ...

# %%
# show specific columns_name & rows
datafiltered[['gender','state','customer lifetime value']][1:15]
# Out:
#    gender       state customer lifetime value
# 1       M  Washington              536307.65%
# 2       M     Arizona              721610.03%
# 3       M      Oregon             2412750.40%
# 4       M  California              473899.20%
# 5       M  Washington              617710.93%
# 6       M  Washington              916206.32%
# 7       M  Washington              495165.61%
# 8       M  Washington              499655.27%
# 9       M      Oregon              247012.12%
# 10      M          AZ              561906.85%
# 11      M      Nevada              366077.03%
# 12      M      Oregon              388545.64%
# 13      M  Washington              254068.98%
# 14      M     Arizona              488516.25%

# %%
# show specific columns_numbers & rows  -- rows(axis0) and columns(axis1) order
datafiltered.iloc[1:15,[1,2,4]]
# Out:
#          state gender   income
# 1   Washington      M  36357.0
# 2      Arizona      M      0.0
# 3       Oregon      M  14072.0
# 4   California      M      0.0
# 5   Washington      M  61040.0
# 6   Washington      M  29723.0
# 7   Washington      M  46896.0
# 8   Washington      M  71600.0
# 9       Oregon      M      0.0
# 10          AZ      M  50335.0
# 11      Nevada      M  64495.0
# 12      Oregon      M      0.0
# 13  Washington      M  42557.0
# 14     Arizona      M  26372.0

# %%
# show specific columns_numbers & rows  -- rows(axis0) and columns(axis1) order
datafiltered.iloc[51:101,5:8]
# Out:
#      monthly premium auto     policy type  vehicle class
# 51                  109.0   Personal Auto            SUV
# 52                   77.0   Personal Auto  Four-Door Car
# 53                  133.0   Personal Auto            SUV
# 54                   84.0   Personal Auto  Four-Door Car
# 55                   62.0   Personal Auto  Four-Door Car
# 56                   67.0   Personal Auto  Four-Door Car
# 57                   83.0   Personal Auto  Four-Door Car
# 58                   63.0  Corporate Auto  Four-Door Car
# 59                   86.0  Corporate Auto  Four-Door Car
# 60                  113.0   Personal Auto            SUV
# 61                  103.0   Personal Auto  Four-Door Car
# 62                   65.0    Special Auto   Two-Door Car
# 63                  111.0  Corporate Auto  Four-Door Car
# 64                   76.0   Personal Auto   Two-Door Car
# 65                   89.0   Personal Auto  Four-Door Car
# ...

# %%
filtered3= datafiltered.reset_index().set_index('customer')

# %%
filtered3
# Out:
#           index       state gender customer lifetime value   income  \
# customer
# WW63253       0  California      M              764586.18%      0.0
# GA49547       1  Washington      M              536307.65%  36357.0
# CF85061       2     Arizona      M              721610.03%      0.0
# DY87989       3      Oregon      M             2412750.40%  14072.0
# SX51350       4  California      M              473899.20%      0.0
# ...         ...         ...    ...                     ...      ...
# TF56202    4363  California      M                 5032.17  66367.0
# LA72316    4364  California      M                   23406  71941.0
# TD14365    4365  California      M                 8163.89      0.0
# UP19263    4366  California      M                 7524.44  21941.0
# Y167826    4367  California      M                 2611.84      0.0
#
#           monthly premium auto     policy type  vehicle class  \
# customer
# WW63253                  106.0  Corporate Auto            SUV
# ...

# %%
#display number of rows in each output
#pd.setoption('display.max_rows',20)
